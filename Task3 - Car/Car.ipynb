# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df1 = df[['Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
       'Fuel_Type', 'Selling_type', 'Transmission', 'Owner']]

# %%
df1.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
print(df['Selling_type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df1['Current_Year'] = 2024

# %%
df1
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Current_Year
# ...

# %%
df1['Age'] = df1['Current_Year'] - df1['Year']

# %%
df1.head()
# Out:
#    Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0  2014           3.35           5.59       27000    Petrol       Dealer
# 1  2013           4.75           9.54       43000    Diesel       Dealer
# 2  2017           7.25           9.85        6900    Petrol       Dealer
# 3  2011           2.85           4.15        5200    Petrol       Dealer
# 4  2014           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Current_Year  Age
# 0       Manual      0          2024   10
# 1       Manual      0          2024   11
# 2       Manual      0          2024    7
# 3       Manual      0          2024   13
# 4       Manual      0          2024   10

# %%
df1.drop(['Year'],axis=1,inplace=True)

# %%
df1.drop(['Current_Year'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0           3.35           5.59       27000    Petrol       Dealer
# 1           4.75           9.54       43000    Diesel       Dealer
# 2           7.25           9.85        6900    Petrol       Dealer
# 3           2.85           4.15        5200    Petrol       Dealer
# 4           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0   10
# 1       Manual      0   11
# 2       Manual      0    7
# 3       Manual      0   13
# 4       Manual      0   10

# %%
df2 = pd.get_dummies(df1,drop_first=True)

# %%
df2.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0   10             False
# 1           4.75           9.54       43000      0   11              True
# 2           7.25           9.85        6900      0    7             False
# 3           2.85           4.15        5200      0   13             False
# 4           4.60           6.87       42450      0   10              True
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0              True                    False                 True
# 1             False                    False                 True
# 2              True                    False                 True
# 3              True                    False                 True
# 4             False                    False                 True

# %%
df2.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Driven_kms', 'Owner', 'Age',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Selling_type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
c2c = ['Driven_kms', 'Owner', 'Age','Fuel_Type_Diesel', 'Fuel_Type_Petrol',
       'Selling_type_Individual', 'Transmission_Manual']

# %%
df2[c2c] = df2[c2c].astype(int)

# %%
print(df2.dtypes)
# Out:
# Selling_Price              float64
# Present_Price              float64
# Driven_kms                   int32
# Owner                        int32
# Age                          int32
# Fuel_Type_Diesel             int32
# Fuel_Type_Petrol             int32
# Selling_type_Individual      int32
# Transmission_Manual          int32
# dtype: object

# %%
df2
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   10                 0
# 1             4.75           9.54       43000      0   11                 1
# 2             7.25           9.85        6900      0    7                 0
# 3             2.85           4.15        5200      0   13                 0
# 4             4.60           6.87       42450      0   10                 1
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    8                 1
# 297           4.00           5.90       60000      0    9                 0
# 298           3.35          11.00       87934      0   15                 0
# 299          11.50          12.50        9000      0    7                 1
# 300           5.30           5.90        5464      0    8                 0
#
# ...

# %%
df2.corr(method='pearson')
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.878914    0.029187 -0.088344
# Present_Price                 0.878914       1.000000    0.203618  0.008058
# Driven_kms                    0.029187       0.203618    1.000000  0.089216
# Owner                        -0.088344       0.008058    0.089216  1.000000
# Age                          -0.236141       0.047192    0.524342  0.182104
# Fuel_Type_Diesel              0.552339       0.473390    0.172515 -0.053469
# Fuel_Type_Petrol             -0.540571      -0.465326   -0.172874  0.055687
# Selling_type_Individual      -0.550724      -0.512121   -0.101419  0.124269
# Transmission_Manual          -0.367128      -0.348776   -0.162510 -0.050316
#
#                               Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# ...

# %%
corrmat = df2.corr(method='pearson')

# %%
corrmat.index
# Out:
# Index(['Selling_Price', 'Present_Price', 'Driven_kms', 'Owner', 'Age',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Selling_type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
import seaborn as sns

corrmat = df2.corr(method = 'pearson')
corr_index = corrmat.index
plt.figure(figsize=(20,20))

#heatmap
g = sns.heatmap(df2[corr_index].corr(method='pearson'),annot = True,cmap = 'RdYlGn')

# %%
df2
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   10                 0
# 1             4.75           9.54       43000      0   11                 1
# 2             7.25           9.85        6900      0    7                 0
# 3             2.85           4.15        5200      0   13                 0
# 4             4.60           6.87       42450      0   10                 1
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    8                 1
# 297           4.00           5.90       60000      0    9                 0
# 298           3.35          11.00       87934      0   15                 0
# 299          11.50          12.50        9000      0    7                 1
# 300           5.30           5.90        5464      0    8                 0
#
# ...

# %%
df2.iloc[:,0]
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
X = df2.iloc[:,1:] # removing selling price for training
Y = df2.iloc[:,0]  # predicting sp

# %%
X.head()
# Out:
#    Present_Price  Driven_kms  Owner  Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0           5.59       27000      0   10                 0                 1
# 1           9.54       43000      0   11                 1                 0
# 2           9.85        6900      0    7                 0                 1
# 3           4.15        5200      0   13                 0                 1
# 4           6.87       42450      0   10                 1                 0
#
#    Selling_type_Individual  Transmission_Manual
# 0                        0                    1
# 1                        0                    1
# 2                        0                    1
# 3                        0                    1
# 4                        0                    1

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.12960144e-01 4.05681797e-02 3.96583211e-04 7.92938351e-02
#  2.14968314e-01 9.52214000e-03 1.15512101e-01 1.26778703e-01]

# %%
# graph for feature importances
feat_imp = pd.Series(model.feature_importances_, index =X.columns)
feat_imp.nlargest(5).plot(kind='bar')
plt.title('Feature Importances')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state = 0)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()

# %%
import numpy as np
n_estimators = [int(x) for x in np.linspace(start = 100,stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
max_features = ['auto','sqrt']   #taking all the features and their square root for training the model
max_depth = [int(x) for x in np.linspace(5,30, num = 6)] #creating tree for each model
min_samples_split  = [2,5,10,15,100] #node-split
min_samples_leaf = [1,2,5,10] #min samples at leaf node

# %%
max_depth
# Out:
# [5, 10, 15, 20, 25, 30]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators' : n_estimators,
               'max_features' : max_features,
               'max_depth' : max_depth,
               'min_samples_split' : min_samples_split,
               'min_samples_leaf' : min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.6s
# ...

# %%
predictions = rf_random.predict(X_test)

# %%
predictions_1 = rf_random.predict(X_train)

# %%
sns.displot(y_test-predictions)

# %%
sns.displot(y_train-predictions_1)

# %%
plt.scatter(y_test,predictions)

# %%
plt.scatter(y_train,predictions_1)

# %%
# Predicted and y_test values are the same

# %%
import pickle
file = open('random_forest_regression_model.pkl','wb')

pickle.dump(rf_random, file)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,predictions)
rmse = np.sqrt(mse)
print("RMSE : {:.2f}".format(rmse))
# Out:
# RMSE : 1.25

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test, predictions)
print("R2 score : {}".format(r))
# Out:
# R2 score : 0.9380340600015477

# %%
df_check = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
df_check = df_check.head(25)
df_check.plot(kind='bar',figsize=(10,5))
plt.grid(which='major', linestyle = '-',linewidth ='0.5', color = 'green')
plt.ylabel('Price')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse_predict = round(mean_squared_error(y_test,predictions),4)
mae_predict = round(mean_absolute_error(y_test,predictions),4)
print('MSE is:'+str(mse_predict))
print('MAE is:'+str(mae_predict))
# Out:
# MSE is:1.5663
# MAE is:0.6031

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cutoff = 1.8
y_pred_classes = np.zeros_like(predictions)
y_test_classes = np.zeros_like(predictions)
y_pred_classes[abs(y_test - predictions) > cutoff] = 1

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)

# %%
df_cm = cm
sns.heatmap(df_cm, annot = True,cmap = 'Blues',annot_kws = {'size': 20})
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import classification_report
matrix = classification_report(y_test_classes, y_pred_classes)
print(matrix)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.93      0.97        61
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.93        61
#    macro avg       0.50      0.47      0.48        61
# weighted avg       1.00      0.93      0.97        61

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test_classes,y_pred_classes)
print('accuracy of the model : {}'.format(ac))
# Out:
# accuracy of the model : 0.9344262295081968
